    'IRC4322': 134, 'IRC4321': 135, 'IRC4320': 136, 'IRC4319': 137, 'IRC4318': 138, 'IRC4317': 139, 'IRC4316': 140,
    'IRC4315': 141, 'IRC4314': 142, 'IRC4313': 143,
    'IRC4473': 144, 'IRC4472': 145, 'IRC4471': 146, 'IRC4470': 147, 'IRC4469': 148, 'IRC4468': 149, 'IRC4467': 150,
    'IRC4466': 151, 'IRC4465': 152, 'IRC4464': 153,
    'IRC4622': 154, 'IRC4620': 155, 'IRC4619': 156, 'IRC4618': 157, 'IRC4617': 158, 'IRC4616': 159, 'IRC4615': 160,
    'IRC4614': 161,
    'IRC4770': 162, 'IRC4769': 163, 'IRC4768': 164, 'IRC4767': 165, 'IRC4766': 166, 'IRC4765': 167, 'IRC4764': 168, 'IRC4763': 169,
    'IRC4918': 170, 'IRC4917': 171, 'IRC4916': 172, 'IRC4915': 173, 'IRC4914': 174,
    'IRC5069': 175, 'IRC5068': 176, 'IRC5067': 177, 'IRC5066': 178, 'IRC5065': 179,
    'IRC5220': 180, 'IRC5219': 181, 'IRC5218': 182, 'IRC5217': 183, 'IRC5216': 184,
    'IRC5370': 185, 'IRC5369': 186, 'IRC5368': 187
}


expected_set = set(expected_codes.keys())

# Generar lista de carpetas desde 2020_01 hasta 2021_12
from datetime import datetime
from dateutil.relativedelta import relativedelta

start = datetime(2022, 1, 1)
end = datetime(2022, 12, 1)

folders = []
while start <= end:
    folders.append(start.strftime('%Y_%m'))
    start += relativedelta(months=1)

# Procesar cada carpeta
for folder in folders:
    folder_path = os.path.join(base_path, folder)

    print(f'\n🔍 Revisando carpeta: {folder_path}')

    if not os.path.exists(folder_path):
        print("⚠️  Carpeta no encontrada. Se omite.")
        continue

    try:
        files = [f for f in os.listdir(folder_path) if f.endswith('.tif')]
        present_codes = set(f.split('_')[1] for f in files if f.startswith('IRC'))

        missing = expected_set - present_codes
        unexpected = present_codes - expected_set

        print(f"📦 Total archivos: {len(files)}")
        print(f"❌ Faltantes: {len(missing)}")
        for code in sorted(missing, key=lambda c: expected_codes.get(c, 9999)):
            print(f"  → FALTANTE: {code}")

        print(f"⚠️  No esperados: {len(unexpected)}")
        for code in sorted(unexpected):
            print(f"  → NO ESPERADO: {code}")

        # Crear carpeta 'no_esperados' si no existe
        backup_path = os.path.join(folder_path, 'no_esperados')
        os.makedirs(backup_path, exist_ok=True)

        # Mover archivos no esperados o con duplicados (parentesis)
        moved_files = []
        for f in files:
            match = re.search(r'(IRC\d{4})(\s*\(\d+\))?', f)
            if match:
                code = match.group(1)
                has_parenthesis = match.group(2) is not None

                if code not in expected_set or has_parenthesis:
                    src = os.path.join(folder_path, f)
                    dst = os.path.join(backup_path, f)
                    try:
                        shutil.move(src, dst)
                        moved_files.append(f)
                    except Exception as e:
                        print(f"⚠️ Error al mover {f}: {e}")

        print(f"📂 Archivos movidos: {len(moved_files)}")
        for f in moved_files:
            print(f"  → MOVIDO: {f}")

    except Exception as e:
        print(f"❗ Error procesando carpeta {folder}: {e}")
# Out:
# 🔍 Revisando carpeta: /content/drive/MyDrive/QLAB PUCP/2022-2024/D - MIDAGRI/imagenes/Anterior/2022_01
# 📦 Total archivos: 187
# ❌ Faltantes: 187
#   → FALTANTE: IRC2056
#   → FALTANTE: IRC2055
#   → FALTANTE: IRC2208
#   → FALTANTE: IRC2207
#   → FALTANTE: IRC2206
#   → FALTANTE: IRC2205
#   → FALTANTE: IRC2204
#   → FALTANTE: IRC2203
#   → FALTANTE: IRC2359
#   → FALTANTE: IRC2358
#   → FALTANTE: IRC2357
#   → FALTANTE: IRC2356
#   → FALTANTE: IRC2355
#   → FALTANTE: IRC2354
#   → FALTANTE: IRC2353
#   → FALTANTE: IRC2352
#   → FALTANTE: IRC2510
#   → FALTANTE: IRC2509
#   → FALTANTE: IRC2508
#   → FALTANTE: IRC2507
#   → FALTANTE: IRC2506
#   → FALTANTE: IRC2505
#   → FALTANTE: IRC2504
#   → FALTANTE: IRC2503
#   → FALTANTE: IRC2502
#   → FALTANTE: IRC2658
#   → FALTANTE: IRC2657
#   → FALTANTE: IRC2656
#   → FALTANTE: IRC2655
#   → FALTANTE: IRC2654
#   → FALTANTE: IRC2653
#   → FALTANTE: IRC2652
#   → FALTANTE: IRC2808
#   → FALTANTE: IRC2807
#   → FALTANTE: IRC2806
#   → FALTANTE: IRC2805
#   → FALTANTE: IRC2804
#   → FALTANTE: IRC2803
#   → FALTANTE: IRC2802
#   → FALTANTE: IRC2959
#   → FALTANTE: IRC2958
#   → FALTANTE: IRC2957
#   → FALTANTE: IRC2956
#   → FALTANTE: IRC2955
#   → FALTANTE: IRC2954
#   → FALTANTE: IRC2953
#   → FALTANTE: IRC2952
#   → FALTANTE: IRC2951
#   → FALTANTE: IRC3111
#   → FALTANTE: IRC3110
#   → FALTANTE: IRC3109
#   → FALTANTE: IRC3108
#   → FALTANTE: IRC3107
#   → FALTANTE: IRC3106
#   → FALTANTE: IRC3105
#   → FALTANTE: IRC3104
#   → FALTANTE: IRC3103
#   → FALTANTE: IRC3102
#   → FALTANTE: IRC3101
#   → FALTANTE: IRC3100
#   → FALTANTE: IRC3262
#   → FALTANTE: IRC3261
#   → FALTANTE: IRC3260
#   → FALTANTE: IRC3259
#   → FALTANTE: IRC3258
#   → FALTANTE: IRC3257
#   → FALTANTE: IRC3256
#   → FALTANTE: IRC3255
#   → FALTANTE: IRC3254
#   → FALTANTE: IRC3253
#   → FALTANTE: IRC3252
#   → FALTANTE: IRC3251
#   → FALTANTE: IRC3250
#   → FALTANTE: IRC3249
#   → FALTANTE: IRC3412
#   → FALTANTE: IRC3411
#   → FALTANTE: IRC3410
#   → FALTANTE: IRC3409
#   → FALTANTE: IRC3408
#   → FALTANTE: IRC3407
#   → FALTANTE: IRC3406
#   → FALTANTE: IRC3405
#   → FALTANTE: IRC3404
#   → FALTANTE: IRC3403
#   → FALTANTE: IRC3402
#   → FALTANTE: IRC3401
#   → FALTANTE: IRC3400
#   → FALTANTE: IRC3563
#   → FALTANTE: IRC3562
#   → FALTANTE: IRC3561
#   → FALTANTE: IRC3560
#   → FALTANTE: IRC3559
#   → FALTANTE: IRC3558
#   → FALTANTE: IRC3557
#   → FALTANTE: IRC3556
#   → FALTANTE: IRC3555
#   → FALTANTE: IRC3554
#   → FALTANTE: IRC3553
#   → FALTANTE: IRC3714
#   → FALTANTE: IRC3713
#   → FALTANTE: IRC3712
#   → FALTANTE: IRC3711
#   → FALTANTE: IRC3710
#   → FALTANTE: IRC3709
#   → FALTANTE: IRC3708
#   → FALTANTE: IRC3707
#   → FALTANTE: IRC3706
#   → FALTANTE: IRC3705
#   → FALTANTE: IRC3864
#   → FALTANTE: IRC3863
#   → FALTANTE: IRC3862
#   → FALTANTE: IRC3861
#   → FALTANTE: IRC3860
#   → FALTANTE: IRC3859
#   → FALTANTE: IRC3858
#   → FALTANTE: IRC3857
#   → FALTANTE: IRC3856
#   → FALTANTE: IRC4020
#   → FALTANTE: IRC4015
#   → FALTANTE: IRC4014
#   → FALTANTE: IRC4013
#   → FALTANTE: IRC4012
#   → FALTANTE: IRC4011
#   → FALTANTE: IRC4010
#   → FALTANTE: IRC4171
#   → FALTANTE: IRC4170
#   → FALTANTE: IRC4169
#   → FALTANTE: IRC4166
#   → FALTANTE: IRC4165
#   → FALTANTE: IRC4164
#   → FALTANTE: IRC4163
#   → FALTANTE: IRC4162
#   → FALTANTE: IRC4161
#   → FALTANTE: IRC4322
#   → FALTANTE: IRC4321
#   → FALTANTE: IRC4320
#   → FALTANTE: IRC4319
#   → FALTANTE: IRC4318
#   → FALTANTE: IRC4317
#   → FALTANTE: IRC4316
#   → FALTANTE: IRC4315
#   → FALTANTE: IRC4314
#   → FALTANTE: IRC4313
#   → FALTANTE: IRC4473
#   → FALTANTE: IRC4472
#   → FALTANTE: IRC4471
#   → FALTANTE: IRC4470
#   → FALTANTE: IRC4469
#   → FALTANTE: IRC4468
#   → FALTANTE: IRC4467
#   → FALTANTE: IRC4466
#   → FALTANTE: IRC4465
#   → FALTANTE: IRC4464
#   → FALTANTE: IRC4622
#   → FALTANTE: IRC4620
#   → FALTANTE: IRC4619
#   → FALTANTE: IRC4618
#   → FALTANTE: IRC4617
#   → FALTANTE: IRC4616
#   → FALTANTE: IRC4615
#   → FALTANTE: IRC4614
#   → FALTANTE: IRC4770
#   → FALTANTE: IRC4769
#   → FALTANTE: IRC4768
#   → FALTANTE: IRC4767
#   → FALTANTE: IRC4766
#   → FALTANTE: IRC4765
#   → FALTANTE: IRC4764
#   → FALTANTE: IRC4763
#   → FALTANTE: IRC4918
#   → FALTANTE: IRC4917
#   → FALTANTE: IRC4916
#   → FALTANTE: IRC4915
#   → FALTANTE: IRC4914
#   → FALTANTE: IRC5069
#   → FALTANTE: IRC5068
#   → FALTANTE: IRC5067
#   → FALTANTE: IRC5066
#   → FALTANTE: IRC5065
#   → FALTANTE: IRC5220
#   → FALTANTE: IRC5219
#   → FALTANTE: IRC5218
#   → FALTANTE: IRC5217
#   → FALTANTE: IRC5216
#   → FALTANTE: IRC5370
#   → FALTANTE: IRC5369
#   → FALTANTE: IRC5368
# ⚠️  No esperados: 0
# 📂 Archivos movidos: 0
#
# 🔍 Revisando carpeta: /content/drive/MyDrive/QLAB PUCP/2022-2024/D - MIDAGRI/imagenes/Anterior/2022_02
# 📦 Total archivos: 187
# ❌ Faltantes: 187
#   → FALTANTE: IRC2056
#   → FALTANTE: IRC2055
#   → FALTANTE: IRC2208
#   → FALTANTE: IRC2207
#   → FALTANTE: IRC2206
#   → FALTANTE: IRC2205
#   → FALTANTE: IRC2204
#   → FALTANTE: IRC2203
#   → FALTANTE: IRC2359
#   → FALTANTE: IRC2358
#   → FALTANTE: IRC2357
#   → FALTANTE: IRC2356
#   → FALTANTE: IRC2355
#   → FALTANTE: IRC2354
#   → FALTANTE: IRC2353
#   → FALTANTE: IRC2352
#   → FALTANTE: IRC2510
#   → FALTANTE: IRC2509
#   → FALTANTE: IRC2508
#   → FALTANTE: IRC2507
#   → FALTANTE: IRC2506
#   → FALTANTE: IRC2505
#   → FALTANTE: IRC2504
#   → FALTANTE: IRC2503
#   → FALTANTE: IRC2502
#   → FALTANTE: IRC2658
#   → FALTANTE: IRC2657
#   → FALTANTE: IRC2656
#   → FALTANTE: IRC2655
#   → FALTANTE: IRC2654
#   → FALTANTE: IRC2653
#   → FALTANTE: IRC2652
#   → FALTANTE: IRC2808
#   → FALTANTE: IRC2807
#   → FALTANTE: IRC2806
#   → FALTANTE: IRC2805
#   → FALTANTE: IRC2804
#   → FALTANTE: IRC2803
#   → FALTANTE: IRC2802
#   → FALTANTE: IRC2959
#   → FALTANTE: IRC2958
#   → FALTANTE: IRC2957
#   → FALTANTE: IRC2956
#   → FALTANTE: IRC2955
#   → FALTANTE: IRC2954
#   → FALTANTE: IRC2953
#   → FALTANTE: IRC2952
#   → FALTANTE: IRC2951
#   → FALTANTE: IRC3111
#   → FALTANTE: IRC3110
#   → FALTANTE: IRC3109
#   → FALTANTE: IRC3108
#   → FALTANTE: IRC3107
#   → FALTANTE: IRC3106
#   → FALTANTE: IRC3105
#   → FALTANTE: IRC3104
#   → FALTANTE: IRC3103
#   → FALTANTE: IRC3102
#   → FALTANTE: IRC3101
#   → FALTANTE: IRC3100
#   → FALTANTE: IRC3262
#   → FALTANTE: IRC3261
#   → FALTANTE: IRC3260
#   → FALTANTE: IRC3259
#   → FALTANTE: IRC3258
#   → FALTANTE: IRC3257
#   → FALTANTE: IRC3256
#   → FALTANTE: IRC3255
#   → FALTANTE: IRC3254
#   → FALTANTE: IRC3253
#   → FALTANTE: IRC3252
#   → FALTANTE: IRC3251
#   → FALTANTE: IRC3250
#   → FALTANTE: IRC3249
#   → FALTANTE: IRC3412
#   → FALTANTE: IRC3411
#   → FALTANTE: IRC3410
#   → FALTANTE: IRC3409
#   → FALTANTE: IRC3408
#   → FALTANTE: IRC3407
#   → FALTANTE: IRC3406
#   → FALTANTE: IRC3405
#   → FALTANTE: IRC3404
#   → FALTANTE: IRC3403
#   → FALTANTE: IRC3402
#   → FALTANTE: IRC3401
#   → FALTANTE: IRC3400
#   → FALTANTE: IRC3563
#   → FALTANTE: IRC3562
#   → FALTANTE: IRC3561
#   → FALTANTE: IRC3560
#   → FALTANTE: IRC3559
#   → FALTANTE: IRC3558
#   → FALTANTE: IRC3557
#   → FALTANTE: IRC3556
#   → FALTANTE: IRC3555
#   → FALTANTE: IRC3554
#   → FALTANTE: IRC3553
#   → FALTANTE: IRC3714
#   → FALTANTE: IRC3713
#   → FALTANTE: IRC3712
#   → FALTANTE: IRC3711
#   → FALTANTE: IRC3710
#   → FALTANTE: IRC3709
#   → FALTANTE: IRC3708
#   → FALTANTE: IRC3707
#   → FALTANTE: IRC3706
#   → FALTANTE: IRC3705
#   → FALTANTE: IRC3864
#   → FALTANTE: IRC3863
#   → FALTANTE: IRC3862
#   → FALTANTE: IRC3861
#   → FALTANTE: IRC3860
#   → FALTANTE: IRC3859
#   → FALTANTE: IRC3858
#   → FALTANTE: IRC3857
#   → FALTANTE: IRC3856
#   → FALTANTE: IRC4020
#   → FALTANTE: IRC4015
#   → FALTANTE: IRC4014
#   → FALTANTE: IRC4013
#   → FALTANTE: IRC4012
#   → FALTANTE: IRC4011
#   → FALTANTE: IRC4010
#   → FALTANTE: IRC4171
#   → FALTANTE: IRC4170
#   → FALTANTE: IRC4169
#   → FALTANTE: IRC4166
#   → FALTANTE: IRC4165
#   → FALTANTE: IRC4164
#   → FALTANTE: IRC4163
#   → FALTANTE: IRC4162
#   → FALTANTE: IRC4161
#   → FALTANTE: IRC4322
#   → FALTANTE: IRC4321
#   → FALTANTE: IRC4320
#   → FALTANTE: IRC4319
#   → FALTANTE: IRC4318
#   → FALTANTE: IRC4317
#   → FALTANTE: IRC4316
#   → FALTANTE: IRC4315
#   → FALTANTE: IRC4314
#   → FALTANTE: IRC4313
#   → FALTANTE: IRC4473
#   → FALTANTE: IRC4472
#   → FALTANTE: IRC4471
#   → FALTANTE: IRC4470
#   → FALTANTE: IRC4469
#   → FALTANTE: IRC4468
#   → FALTANTE: IRC4467
#   → FALTANTE: IRC4466
#   → FALTANTE: IRC4465
#   → FALTANTE: IRC4464
#   → FALTANTE: IRC4622
#   → FALTANTE: IRC4620
#   → FALTANTE: IRC4619
#   → FALTANTE: IRC4618
#   → FALTANTE: IRC4617
#   → FALTANTE: IRC4616
#   → FALTANTE: IRC4615
#   → FALTANTE: IRC4614
#   → FALTANTE: IRC4770
#   → FALTANTE: IRC4769
#   → FALTANTE: IRC4768
#   → FALTANTE: IRC4767
#   → FALTANTE: IRC4766
#   → FALTANTE: IRC4765
#   → FALTANTE: IRC4764
#   → FALTANTE: IRC4763
#   → FALTANTE: IRC4918
#   → FALTANTE: IRC4917
#   → FALTANTE: IRC4916
#   → FALTANTE: IRC4915
#   → FALTANTE: IRC4914
#   → FALTANTE: IRC5069
#   → FALTANTE: IRC5068
#   → FALTANTE: IRC5067
#   → FALTANTE: IRC5066
#   → FALTANTE: IRC5065
#   → FALTANTE: IRC5220
#   → FALTANTE: IRC5219
#   → FALTANTE: IRC5218
#   → FALTANTE: IRC5217
#   → FALTANTE: IRC5216
#   → FALTANTE: IRC5370
#   → FALTANTE: IRC5369
#   → FALTANTE: IRC5368
# ⚠️  No esperados: 0
# 📂 Archivos movidos: 0
#
# 🔍 Revisando carpeta: /content/drive/MyDrive/QLAB PUCP/2022-2024/D - MIDAGRI/imagenes/Anterior/2022_03
# 📦 Total archivos: 186
# ❌ Faltantes: 187
#   → FALTANTE: IRC2056
#   → FALTANTE: IRC2055
#   → FALTANTE: IRC2208
#   → FALTANTE: IRC2207
#   → FALTANTE: IRC2206
#   → FALTANTE: IRC2205
#   → FALTANTE: IRC2204
#   → FALTANTE: IRC2203
#   → FALTANTE: IRC2359
#   → FALTANTE: IRC2358
#   → FALTANTE: IRC2357
#   → FALTANTE: IRC2356
#   → FALTANTE: IRC2355
#   → FALTANTE: IRC2354
#   → FALTANTE: IRC2353
#   → FALTANTE: IRC2352
#   → FALTANTE: IRC2510
#   → FALTANTE: IRC2509
#   → FALTANTE: IRC2508
#   → FALTANTE: IRC2507
#   → FALTANTE: IRC2506
#   → FALTANTE: IRC2505
#   → FALTANTE: IRC2504
#   → FALTANTE: IRC2503
#   → FALTANTE: IRC2502
#   → FALTANTE: IRC2658
#   → FALTANTE: IRC2657
#   → FALTANTE: IRC2656
#   → FALTANTE: IRC2655
#   → FALTANTE: IRC2654
#   → FALTANTE: IRC2653
#   → FALTANTE: IRC2652
#   → FALTANTE: IRC2808
#   → FALTANTE: IRC2807
#   → FALTANTE: IRC2806
#   → FALTANTE: IRC2805
#   → FALTANTE: IRC2804
#   → FALTANTE: IRC2803
#   → FALTANTE: IRC2802
#   → FALTANTE: IRC2959
#   → FALTANTE: IRC2958
#   → FALTANTE: IRC2957
#   → FALTANTE: IRC2956
#   → FALTANTE: IRC2955
#   → FALTANTE: IRC2954
#   → FALTANTE: IRC2953
#   → FALTANTE: IRC2952
#   → FALTANTE: IRC2951
#   → FALTANTE: IRC3111
#   → FALTANTE: IRC3110
#   → FALTANTE: IRC3109
#   → FALTANTE: IRC3108
#   → FALTANTE: IRC3107
#   → FALTANTE: IRC3106
#   → FALTANTE: IRC3105
#   → FALTANTE: IRC3104
#   → FALTANTE: IRC3103
#   → FALTANTE: IRC3102
#   → FALTANTE: IRC3101
#   → FALTANTE: IRC3100
#   → FALTANTE: IRC3262
#   → FALTANTE: IRC3261
#   → FALTANTE: IRC3260
#   → FALTANTE: IRC3259
#   → FALTANTE: IRC3258
#   → FALTANTE: IRC3257
#   → FALTANTE: IRC3256
#   → FALTANTE: IRC3255
#   → FALTANTE: IRC3254
#   → FALTANTE: IRC3253
#   → FALTANTE: IRC3252
#   → FALTANTE: IRC3251
#   → FALTANTE: IRC3250
#   → FALTANTE: IRC3249
#   → FALTANTE: IRC3412
#   → FALTANTE: IRC3411
#   → FALTANTE: IRC3410
#   → FALTANTE: IRC3409
#   → FALTANTE: IRC3408
#   → FALTANTE: IRC3407
#   → FALTANTE: IRC3406
#   → FALTANTE: IRC3405
#   → FALTANTE: IRC3404
#   → FALTANTE: IRC3403
#   → FALTANTE: IRC3402
#   → FALTANTE: IRC3401
#   → FALTANTE: IRC3400
#   → FALTANTE: IRC3563
#   → FALTANTE: IRC3562
#   → FALTANTE: IRC3561
#   → FALTANTE: IRC3560
#   → FALTANTE: IRC3559
#   → FALTANTE: IRC3558
#   → FALTANTE: IRC3557
#   → FALTANTE: IRC3556
#   → FALTANTE: IRC3555
#   → FALTANTE: IRC3554
#   → FALTANTE: IRC3553
#   → FALTANTE: IRC3714
#   → FALTANTE: IRC3713
#   → FALTANTE: IRC3712
#   → FALTANTE: IRC3711
#   → FALTANTE: IRC3710
#   → FALTANTE: IRC3709
#   → FALTANTE: IRC3708
#   → FALTANTE: IRC3707
#   → FALTANTE: IRC3706
#   → FALTANTE: IRC3705
#   → FALTANTE: IRC3864
#   → FALTANTE: IRC3863
#   → FALTANTE: IRC3862
#   → FALTANTE: IRC3861
#   → FALTANTE: IRC3860
#   → FALTANTE: IRC3859
#   → FALTANTE: IRC3858
#   → FALTANTE: IRC3857
#   → FALTANTE: IRC3856
#   → FALTANTE: IRC4020
#   → FALTANTE: IRC4015
#   → FALTANTE: IRC4014
#   → FALTANTE: IRC4013
#   → FALTANTE: IRC4012
#   → FALTANTE: IRC4011
#   → FALTANTE: IRC4010
#   → FALTANTE: IRC4171
#   → FALTANTE: IRC4170
#   → FALTANTE: IRC4169
#   → FALTANTE: IRC4166
#   → FALTANTE: IRC4165
#   → FALTANTE: IRC4164
#   → FALTANTE: IRC4163
#   → FALTANTE: IRC4162
#   → FALTANTE: IRC4161
#   → FALTANTE: IRC4322
#   → FALTANTE: IRC4321
#   → FALTANTE: IRC4320
#   → FALTANTE: IRC4319
#   → FALTANTE: IRC4318
#   → FALTANTE: IRC4317
#   → FALTANTE: IRC4316
#   → FALTANTE: IRC4315
#   → FALTANTE: IRC4314
#   → FALTANTE: IRC4313
#   → FALTANTE: IRC4473
#   → FALTANTE: IRC4472
#   → FALTANTE: IRC4471
#   → FALTANTE: IRC4470
#   → FALTANTE: IRC4469
#   → FALTANTE: IRC4468
#   → FALTANTE: IRC4467
#   → FALTANTE: IRC4466
#   → FALTANTE: IRC4465
#   → FALTANTE: IRC4464
#   → FALTANTE: IRC4622
#   → FALTANTE: IRC4620
#   → FALTANTE: IRC4619
#   → FALTANTE: IRC4618
#   → FALTANTE: IRC4617
#   → FALTANTE: IRC4616
#   → FALTANTE: IRC4615
#   → FALTANTE: IRC4614
#   → FALTANTE: IRC4770
#   → FALTANTE: IRC4769
#   → FALTANTE: IRC4768
#   → FALTANTE: IRC4767
#   → FALTANTE: IRC4766
#   → FALTANTE: IRC4765
#   → FALTANTE: IRC4764
#   → FALTANTE: IRC4763
#   → FALTANTE: IRC4918
#   → FALTANTE: IRC4917
#   → FALTANTE: IRC4916
#   → FALTANTE: IRC4915
#   → FALTANTE: IRC4914
#   → FALTANTE: IRC5069
#   → FALTANTE: IRC5068
#   → FALTANTE: IRC5067
#   → FALTANTE: IRC5066
#   → FALTANTE: IRC5065
#   → FALTANTE: IRC5220
#   → FALTANTE: IRC5219
#   → FALTANTE: IRC5218
#   → FALTANTE: IRC5217
#   → FALTANTE: IRC5216
#   → FALTANTE: IRC5370
#   → FALTANTE: IRC5369
#   → FALTANTE: IRC5368
# ⚠️  No esperados: 0
# 📂 Archivos movidos: 0
#
# 🔍 Revisando carpeta: /content/drive/MyDrive/QLAB PUCP/2022-2024/D - MIDAGRI/imagenes/Anterior/2022_04
# 📦 Total archivos: 187
# ❌ Faltantes: 187
#   → FALTANTE: IRC2056
#   → FALTANTE: IRC2055
#   → FALTANTE: IRC2208
#   → FALTANTE: IRC2207
#   → FALTANTE: IRC2206
#   → FALTANTE: IRC2205
#   → FALTANTE: IRC2204
#   → FALTANTE: IRC2203
#   → FALTANTE: IRC2359
#   → FALTANTE: IRC2358
#   → FALTANTE: IRC2357
#   → FALTANTE: IRC2356
#   → FALTANTE: IRC2355
#   → FALTANTE: IRC2354
#   → FALTANTE: IRC2353
#   → FALTANTE: IRC2352
#   → FALTANTE: IRC2510
#   → FALTANTE: IRC2509
#   → FALTANTE: IRC2508
#   → FALTANTE: IRC2507
#   → FALTANTE: IRC2506
#   → FALTANTE: IRC2505
#   → FALTANTE: IRC2504
#   → FALTANTE: IRC2503
#   → FALTANTE: IRC2502
#   → FALTANTE: IRC2658
#   → FALTANTE: IRC2657
#   → FALTANTE: IRC2656
#   → FALTANTE: IRC2655
#   → FALTANTE: IRC2654
#   → FALTANTE: IRC2653
#   → FALTANTE: IRC2652
#   → FALTANTE: IRC2808
#   → FALTANTE: IRC2807
#   → FALTANTE: IRC2806
#   → FALTANTE: IRC2805
#   → FALTANTE: IRC2804
#   → FALTANTE: IRC2803
#   → FALTANTE: IRC2802
#   → FALTANTE: IRC2959
#   → FALTANTE: IRC2958
#   → FALTANTE: IRC2957
#   → FALTANTE: IRC2956
#   → FALTANTE: IRC2955
#   → FALTANTE: IRC2954
#   → FALTANTE: IRC2953
#   → FALTANTE: IRC2952
#   → FALTANTE: IRC2951
#   → FALTANTE: IRC3111
#   → FALTANTE: IRC3110
#   → FALTANTE: IRC3109
#   → FALTANTE: IRC3108
#   → FALTANTE: IRC3107
#   → FALTANTE: IRC3106
#   → FALTANTE: IRC3105
#   → FALTANTE: IRC3104
#   → FALTANTE: IRC3103
#   → FALTANTE: IRC3102
#   → FALTANTE: IRC3101
#   → FALTANTE: IRC3100
#   → FALTANTE: IRC3262
#   → FALTANTE: IRC3261
#   → FALTANTE: IRC3260
#   → FALTANTE: IRC3259
#   → FALTANTE: IRC3258
#   → FALTANTE: IRC3257
#   → FALTANTE: IRC3256
#   → FALTANTE: IRC3255
#   → FALTANTE: IRC3254
#   → FALTANTE: IRC3253
#   → FALTANTE: IRC3252
#   → FALTANTE: IRC3251
#   → FALTANTE: IRC3250
#   → FALTANTE: IRC3249
#   → FALTANTE: IRC3412
#   → FALTANTE: IRC3411
#   → FALTANTE: IRC3410
#   → FALTANTE: IRC3409
#   → FALTANTE: IRC3408
#   → FALTANTE: IRC3407
#   → FALTANTE: IRC3406
#   → FALTANTE: IRC3405
#   → FALTANTE: IRC3404
#   → FALTANTE: IRC3403
#   → FALTANTE: IRC3402
#   → FALTANTE: IRC3401
#   → FALTANTE: IRC3400
#   → FALTANTE: IRC3563
#   → FALTANTE: IRC3562
#   → FALTANTE: IRC3561
#   → FALTANTE: IRC3560
#   → FALTANTE: IRC3559
#   → FALTANTE: IRC3558
#   → FALTANTE: IRC3557
#   → FALTANTE: IRC3556
#   → FALTANTE: IRC3555
#   → FALTANTE: IRC3554
#   → FALTANTE: IRC3553
#   → FALTANTE: IRC3714
#   → FALTANTE: IRC3713
#   → FALTANTE: IRC3712
#   → FALTANTE: IRC3711
#   → FALTANTE: IRC3710
#   → FALTANTE: IRC3709
#   → FALTANTE: IRC3708
#   → FALTANTE: IRC3707
#   → FALTANTE: IRC3706
#   → FALTANTE: IRC3705
#   → FALTANTE: IRC3864
#   → FALTANTE: IRC3863
#   → FALTANTE: IRC3862
#   → FALTANTE: IRC3861
#   → FALTANTE: IRC3860
#   → FALTANTE: IRC3859
#   → FALTANTE: IRC3858
#   → FALTANTE: IRC3857
#   → FALTANTE: IRC3856
#   → FALTANTE: IRC4020
#   → FALTANTE: IRC4015
#   → FALTANTE: IRC4014
#   → FALTANTE: IRC4013
#   → FALTANTE: IRC4012
#   → FALTANTE: IRC4011
#   → FALTANTE: IRC4010
#   → FALTANTE: IRC4171
#   → FALTANTE: IRC4170
#   → FALTANTE: IRC4169
#   → FALTANTE: IRC4166
#   → FALTANTE: IRC4165
#   → FALTANTE: IRC4164
#   → FALTANTE: IRC4163
#   → FALTANTE: IRC4162
#   → FALTANTE: IRC4161
#   → FALTANTE: IRC4322
#   → FALTANTE: IRC4321
#   → FALTANTE: IRC4320
#   → FALTANTE: IRC4319
#   → FALTANTE: IRC4318
#   → FALTANTE: IRC4317
#   → FALTANTE: IRC4316
#   → FALTANTE: IRC4315
#   → FALTANTE: IRC4314
#   → FALTANTE: IRC4313
#   → FALTANTE: IRC4473
#   → FALTANTE: IRC4472
#   → FALTANTE: IRC4471
#   → FALTANTE: IRC4470
#   → FALTANTE: IRC4469
#   → FALTANTE: IRC4468
#   → FALTANTE: IRC4467
#   → FALTANTE: IRC4466
#   → FALTANTE: IRC4465
#   → FALTANTE: IRC4464
#   → FALTANTE: IRC4622
#   → FALTANTE: IRC4620
#   → FALTANTE: IRC4619
#   → FALTANTE: IRC4618
#   → FALTANTE: IRC4617
#   → FALTANTE: IRC4616
#   → FALTANTE: IRC4615
#   → FALTANTE: IRC4614
#   → FALTANTE: IRC4770
#   → FALTANTE: IRC4769
#   → FALTANTE: IRC4768
#   → FALTANTE: IRC4767
#   → FALTANTE: IRC4766
#   → FALTANTE: IRC4765
#   → FALTANTE: IRC4764
#   → FALTANTE: IRC4763
#   → FALTANTE: IRC4918
#   → FALTANTE: IRC4917
#   → FALTANTE: IRC4916
#   → FALTANTE: IRC4915
#   → FALTANTE: IRC4914
#   → FALTANTE: IRC5069
#   → FALTANTE: IRC5068
#   → FALTANTE: IRC5067
#   → FALTANTE: IRC5066
#   → FALTANTE: IRC5065
#   → FALTANTE: IRC5220
#   → FALTANTE: IRC5219
#   → FALTANTE: IRC5218
#   → FALTANTE: IRC5217
#   → FALTANTE: IRC5216
#   → FALTANTE: IRC5370
#   → FALTANTE: IRC5369
#   → FALTANTE: IRC5368
# ⚠️  No esperados: 0
# 📂 Archivos movidos: 0
#
# 🔍 Revisando carpeta: /content/drive/MyDrive/QLAB PUCP/2022-2024/D - MIDAGRI/imagenes/Anterior/2022_05
# 📦 Total archivos: 186
# ❌ Faltantes: 187
#   → FALTANTE: IRC2056
#   → FALTANTE: IRC2055
#   → FALTANTE: IRC2208
#   → FALTANTE: IRC2207
#   → FALTANTE: IRC2206
#   → FALTANTE: IRC2205
#   → FALTANTE: IRC2204
#   → FALTANTE: IRC2203
#   → FALTANTE: IRC2359
#   → FALTANTE: IRC2358
#   → FALTANTE: IRC2357
#   → FALTANTE: IRC2356
#   → FALTANTE: IRC2355
#   → FALTANTE: IRC2354
#   → FALTANTE: IRC2353
#   → FALTANTE: IRC2352
#   → FALTANTE: IRC2510
#   → FALTANTE: IRC2509
#   → FALTANTE: IRC2508
#   → FALTANTE: IRC2507
#   → FALTANTE: IRC2506
#   → FALTANTE: IRC2505
#   → FALTANTE: IRC2504
#   → FALTANTE: IRC2503
#   → FALTANTE: IRC2502
#   → FALTANTE: IRC2658
#   → FALTANTE: IRC2657
#   → FALTANTE: IRC2656
#   → FALTANTE: IRC2655
#   → FALTANTE: IRC2654
#   → FALTANTE: IRC2653
#   → FALTANTE: IRC2652
#   → FALTANTE: IRC2808
#   → FALTANTE: IRC2807
#   → FALTANTE: IRC2806
#   → FALTANTE: IRC2805
#   → FALTANTE: IRC2804
#   → FALTANTE: IRC2803
#   → FALTANTE: IRC2802
#   → FALTANTE: IRC2959
#   → FALTANTE: IRC2958
#   → FALTANTE: IRC2957
#   → FALTANTE: IRC2956
#   → FALTANTE: IRC2955
#   → FALTANTE: IRC2954
#   → FALTANTE: IRC2953
#   → FALTANTE: IRC2952
#   → FALTANTE: IRC2951
#   → FALTANTE: IRC3111
#   → FALTANTE: IRC3110
#   → FALTANTE: IRC3109
#   → FALTANTE: IRC3108
#   → FALTANTE: IRC3107
#   → FALTANTE: IRC3106
#   → FALTANTE: IRC3105
#   → FALTANTE: IRC3104
#   → FALTANTE: IRC3103
#   → FALTANTE: IRC3102
#   → FALTANTE: IRC3101
#   → FALTANTE: IRC3100
#   → FALTANTE: IRC3262
#   → FALTANTE: IRC3261
#   → FALTANTE: IRC3260
#   → FALTANTE: IRC3259
#   → FALTANTE: IRC3258
#   → FALTANTE: IRC3257
#   → FALTANTE: IRC3256
#   → FALTANTE: IRC3255
#   → FALTANTE: IRC3254
#   → FALTANTE: IRC3253
#   → FALTANTE: IRC3252
#   → FALTANTE: IRC3251
#   → FALTANTE: IRC3250
#   → FALTANTE: IRC3249
#   → FALTANTE: IRC3412
#   → FALTANTE: IRC3411
#   → FALTANTE: IRC3410
#   → FALTANTE: IRC3409
#   → FALTANTE: IRC3408
#   → FALTANTE: IRC3407
#   → FALTANTE: IRC3406
#   → FALTANTE: IRC3405
#   → FALTANTE: IRC3404
#   → FALTANTE: IRC3403
#   → FALTANTE: IRC3402
#   → FALTANTE: IRC3401
#   → FALTANTE: IRC3400
#   → FALTANTE: IRC3563
#   → FALTANTE: IRC3562
#   → FALTANTE: IRC3561
#   → FALTANTE: IRC3560
#   → FALTANTE: IRC3559
#   → FALTANTE: IRC3558
#   → FALTANTE: IRC3557
#   → FALTANTE: IRC3556
#   → FALTANTE: IRC3555
#   → FALTANTE: IRC3554
#   → FALTANTE: IRC3553
#   → FALTANTE: IRC3714
#   → FALTANTE: IRC3713
#   → FALTANTE: IRC3712
#   → FALTANTE: IRC3711
#   → FALTANTE: IRC3710
#   → FALTANTE: IRC3709
#   → FALTANTE: IRC3708
#   → FALTANTE: IRC3707
#   → FALTANTE: IRC3706
#   → FALTANTE: IRC3705
#   → FALTANTE: IRC3864
#   → FALTANTE: IRC3863
#   → FALTANTE: IRC3862
#   → FALTANTE: IRC3861
#   → FALTANTE: IRC3860
#   → FALTANTE: IRC3859
#   → FALTANTE: IRC3858
#   → FALTANTE: IRC3857
#   → FALTANTE: IRC3856
#   → FALTANTE: IRC4020
#   → FALTANTE: IRC4015
#   → FALTANTE: IRC4014
#   → FALTANTE: IRC4013
#   → FALTANTE: IRC4012
#   → FALTANTE: IRC4011
#   → FALTANTE: IRC4010
#   → FALTANTE: IRC4171
#   → FALTANTE: IRC4170
#   → FALTANTE: IRC4169
#   → FALTANTE: IRC4166
#   → FALTANTE: IRC4165
#   → FALTANTE: IRC4164
#   → FALTANTE: IRC4163
#   → FALTANTE: IRC4162
#   → FALTANTE: IRC4161
#   → FALTANTE: IRC4322
#   → FALTANTE: IRC4321
#   → FALTANTE: IRC4320
#   → FALTANTE: IRC4319
#   → FALTANTE: IRC4318
#   → FALTANTE: IRC4317
#   → FALTANTE: IRC4316
#   → FALTANTE: IRC4315
#   → FALTANTE: IRC4314
#   → FALTANTE: IRC4313
#   → FALTANTE: IRC4473
#   → FALTANTE: IRC4472
#   → FALTANTE: IRC4471
#   → FALTANTE: IRC4470
#   → FALTANTE: IRC4469
#   → FALTANTE: IRC4468
#   → FALTANTE: IRC4467
#   → FALTANTE: IRC4466
#   → FALTANTE: IRC4465
#   → FALTANTE: IRC4464
#   → FALTANTE: IRC4622
#   → FALTANTE: IRC4620
#   → FALTANTE: IRC4619
#   → FALTANTE: IRC4618
#   → FALTANTE: IRC4617
#   → FALTANTE: IRC4616
#   → FALTANTE: IRC4615
#   → FALTANTE: IRC4614
#   → FALTANTE: IRC4770
#   → FALTANTE: IRC4769
#   → FALTANTE: IRC4768
#   → FALTANTE: IRC4767
#   → FALTANTE: IRC4766
#   → FALTANTE: IRC4765
#   → FALTANTE: IRC4764
#   → FALTANTE: IRC4763
#   → FALTANTE: IRC4918
#   → FALTANTE: IRC4917
#   → FALTANTE: IRC4916
#   → FALTANTE: IRC4915
#   → FALTANTE: IRC4914
#   → FALTANTE: IRC5069
#   → FALTANTE: IRC5068
#   → FALTANTE: IRC5067
#   → FALTANTE: IRC5066
#   → FALTANTE: IRC5065
#   → FALTANTE: IRC5220
#   → FALTANTE: IRC5219
#   → FALTANTE: IRC5218
#   → FALTANTE: IRC5217
#   → FALTANTE: IRC5216
#   → FALTANTE: IRC5370
#   → FALTANTE: IRC5369
#   → FALTANTE: IRC5368
# ⚠️  No esperados: 0
# 📂 Archivos movidos: 0
#
# 🔍 Revisando carpeta: /content/drive/MyDrive/QLAB PUCP/2022-2024/D - MIDAGRI/imagenes/Anterior/2022_06
# 📦 Total archivos: 187
# ❌ Faltantes: 187
#   → FALTANTE: IRC2056
#   → FALTANTE: IRC2055
#   → FALTANTE: IRC2208
#   → FALTANTE: IRC2207
#   → FALTANTE: IRC2206
#   → FALTANTE: IRC2205
#   → FALTANTE: IRC2204
#   → FALTANTE: IRC2203
#   → FALTANTE: IRC2359
#   → FALTANTE: IRC2358
#   → FALTANTE: IRC2357
#   → FALTANTE: IRC2356
#   → FALTANTE: IRC2355
#   → FALTANTE: IRC2354
#   → FALTANTE: IRC2353
#   → FALTANTE: IRC2352
#   → FALTANTE: IRC2510
#   → FALTANTE: IRC2509
#   → FALTANTE: IRC2508
#   → FALTANTE: IRC2507
#   → FALTANTE: IRC2506
#   → FALTANTE: IRC2505
#   → FALTANTE: IRC2504
#   → FALTANTE: IRC2503
#   → FALTANTE: IRC2502
#   → FALTANTE: IRC2658
#   → FALTANTE: IRC2657
#   → FALTANTE: IRC2656
#   → FALTANTE: IRC2655
#   → FALTANTE: IRC2654
#   → FALTANTE: IRC2653
#   → FALTANTE: IRC2652
#   → FALTANTE: IRC2808
#   → FALTANTE: IRC2807
#   → FALTANTE: IRC2806
#   → FALTANTE: IRC2805
#   → FALTANTE: IRC2804
#   → FALTANTE: IRC2803
#   → FALTANTE: IRC2802
#   → FALTANTE: IRC2959
#   → FALTANTE: IRC2958
#   → FALTANTE: IRC2957
#   → FALTANTE: IRC2956
#   → FALTANTE: IRC2955
#   → FALTANTE: IRC2954
#   → FALTANTE: IRC2953
#   → FALTANTE: IRC2952
#   → FALTANTE: IRC2951
#   → FALTANTE: IRC3111
#   → FALTANTE: IRC3110
#   → FALTANTE: IRC3109
#   → FALTANTE: IRC3108
#   → FALTANTE: IRC3107
#   → FALTANTE: IRC3106
#   → FALTANTE: IRC3105
#   → FALTANTE: IRC3104
#   → FALTANTE: IRC3103
#   → FALTANTE: IRC3102
#   → FALTANTE: IRC3101
#   → FALTANTE: IRC3100
#   → FALTANTE: IRC3262
#   → FALTANTE: IRC3261
#   → FALTANTE: IRC3260
#   → FALTANTE: IRC3259
#   → FALTANTE: IRC3258
#   → FALTANTE: IRC3257
#   → FALTANTE: IRC3256
#   → FALTANTE: IRC3255
#   → FALTANTE: IRC3254
#   → FALTANTE: IRC3253
#   → FALTANTE: IRC3252
#   → FALTANTE: IRC3251
#   → FALTANTE: IRC3250
#   → FALTANTE: IRC3249
#   → FALTANTE: IRC3412
#   → FALTANTE: IRC3411
#   → FALTANTE: IRC3410
#   → FALTANTE: IRC3409
#   → FALTANTE: IRC3408
#   → FALTANTE: IRC3407
#   → FALTANTE: IRC3406
#   → FALTANTE: IRC3405
#   → FALTANTE: IRC3404
#   → FALTANTE: IRC3403
#   → FALTANTE: IRC3402
#   → FALTANTE: IRC3401
#   → FALTANTE: IRC3400
#   → FALTANTE: IRC3563
#   → FALTANTE: IRC3562
#   → FALTANTE: IRC3561
#   → FALTANTE: IRC3560
#   → FALTANTE: IRC3559
#   → FALTANTE: IRC3558
#   → FALTANTE: IRC3557
#   → FALTANTE: IRC3556
#   → FALTANTE: IRC3555
#   → FALTANTE: IRC3554
#   → FALTANTE: IRC3553
#   → FALTANTE: IRC3714
#   → FALTANTE: IRC3713
#   → FALTANTE: IRC3712
#   → FALTANTE: IRC3711
#   → FALTANTE: IRC3710
#   → FALTANTE: IRC3709
#   → FALTANTE: IRC3708
#   → FALTANTE: IRC3707
#   → FALTANTE: IRC3706
#   → FALTANTE: IRC3705
#   → FALTANTE: IRC3864
#   → FALTANTE: IRC3863
#   → FALTANTE: IRC3862
#   → FALTANTE: IRC3861
#   → FALTANTE: IRC3860
#   → FALTANTE: IRC3859
#   → FALTANTE: IRC3858
#   → FALTANTE: IRC3857
#   → FALTANTE: IRC3856
#   → FALTANTE: IRC4020
#   → FALTANTE: IRC4015
#   → FALTANTE: IRC4014
#   → FALTANTE: IRC4013
#   → FALTANTE: IRC4012
#   → FALTANTE: IRC4011
#   → FALTANTE: IRC4010
#   → FALTANTE: IRC4171
#   → FALTANTE: IRC4170
#   → FALTANTE: IRC4169
#   → FALTANTE: IRC4166
#   → FALTANTE: IRC4165
#   → FALTANTE: IRC4164
#   → FALTANTE: IRC4163
#   → FALTANTE: IRC4162
#   → FALTANTE: IRC4161
#   → FALTANTE: IRC4322
#   → FALTANTE: IRC4321
#   → FALTANTE: IRC4320
#   → FALTANTE: IRC4319
#   → FALTANTE: IRC4318
#   → FALTANTE: IRC4317
#   → FALTANTE: IRC4316
#   → FALTANTE: IRC4315
#   → FALTANTE: IRC4314
#   → FALTANTE: IRC4313
#   → FALTANTE: IRC4473
#   → FALTANTE: IRC4472
#   → FALTANTE: IRC4471
#   → FALTANTE: IRC4470
#   → FALTANTE: IRC4469
#   → FALTANTE: IRC4468
#   → FALTANTE: IRC4467
#   → FALTANTE: IRC4466
#   → FALTANTE: IRC4465
#   → FALTANTE: IRC4464
#   → FALTANTE: IRC4622
#   → FALTANTE: IRC4620
#   → FALTANTE: IRC4619
#   → FALTANTE: IRC4618
#   → FALTANTE: IRC4617
#   → FALTANTE: IRC4616
#   → FALTANTE: IRC4615
#   → FALTANTE: IRC4614
#   → FALTANTE: IRC4770
#   → FALTANTE: IRC4769
#   → FALTANTE: IRC4768
#   → FALTANTE: IRC4767
#   → FALTANTE: IRC4766
#   → FALTANTE: IRC4765
#   → FALTANTE: IRC4764
#   → FALTANTE: IRC4763
#   → FALTANTE: IRC4918
#   → FALTANTE: IRC4917
#   → FALTANTE: IRC4916
#   → FALTANTE: IRC4915
#   → FALTANTE: IRC4914
#   → FALTANTE: IRC5069
#   → FALTANTE: IRC5068
#   → FALTANTE: IRC5067
#   → FALTANTE: IRC5066
#   → FALTANTE: IRC5065
#   → FALTANTE: IRC5220
#   → FALTANTE: IRC5219
#   → FALTANTE: IRC5218
#   → FALTANTE: IRC5217
#   → FALTANTE: IRC5216
#   → FALTANTE: IRC5370
#   → FALTANTE: IRC5369
#   → FALTANTE: IRC5368
# ⚠️  No esperados: 0
# 📂 Archivos movidos: 0
#
# 🔍 Revisando carpeta: /content/drive/MyDrive/QLAB PUCP/2022-2024/D - MIDAGRI/imagenes/Anterior/2022_07
# 📦 Total archivos: 186
# ❌ Faltantes: 187
#   → FALTANTE: IRC2056
#   → FALTANTE: IRC2055
#   → FALTANTE: IRC2208
#   → FALTANTE: IRC2207
#   → FALTANTE: IRC2206
#   → FALTANTE: IRC2205
#   → FALTANTE: IRC2204
#   → FALTANTE: IRC2203
#   → FALTANTE: IRC2359
#   → FALTANTE: IRC2358
#   → FALTANTE: IRC2357
#   → FALTANTE: IRC2356
#   → FALTANTE: IRC2355
#   → FALTANTE: IRC2354
#   → FALTANTE: IRC2353
#   → FALTANTE: IRC2352
#   → FALTANTE: IRC2510
#   → FALTANTE: IRC2509
#   → FALTANTE: IRC2508
#   → FALTANTE: IRC2507
#   → FALTANTE: IRC2506
#   → FALTANTE: IRC2505
#   → FALTANTE: IRC2504
#   → FALTANTE: IRC2503
#   → FALTANTE: IRC2502
#   → FALTANTE: IRC2658
#   → FALTANTE: IRC2657
#   → FALTANTE: IRC2656
#   → FALTANTE: IRC2655
#   → FALTANTE: IRC2654
#   → FALTANTE: IRC2653
#   → FALTANTE: IRC2652
#   → FALTANTE: IRC2808
#   → FALTANTE: IRC2807
#   → FALTANTE: IRC2806
#   → FALTANTE: IRC2805
#   → FALTANTE: IRC2804
#   → FALTANTE: IRC2803
#   → FALTANTE: IRC2802
#   → FALTANTE: IRC2959
#   → FALTANTE: IRC2958
#   → FALTANTE: IRC2957
#   → FALTANTE: IRC2956
#   → FALTANTE: IRC2955
#   → FALTANTE: IRC2954
#   → FALTANTE: IRC2953
#   → FALTANTE: IRC2952
#   → FALTANTE: IRC2951
#   → FALTANTE: IRC3111
#   → FALTANTE: IRC3110
#   → FALTANTE: IRC3109
#   → FALTANTE: IRC3108
#   → FALTANTE: IRC3107
#   → FALTANTE: IRC3106
#   → FALTANTE: IRC3105
#   → FALTANTE: IRC3104
#   → FALTANTE: IRC3103
#   → FALTANTE: IRC3102
#   → FALTANTE: IRC3101
#   → FALTANTE: IRC3100
#   → FALTANTE: IRC3262
#   → FALTANTE: IRC3261
#   → FALTANTE: IRC3260
#   → FALTANTE: IRC3259
#   → FALTANTE: IRC3258
#   → FALTANTE: IRC3257
#   → FALTANTE: IRC3256
#   → FALTANTE: IRC3255
#   → FALTANTE: IRC3254
#   → FALTANTE: IRC3253
#   → FALTANTE: IRC3252
#   → FALTANTE: IRC3251
#   → FALTANTE: IRC3250
#   → FALTANTE: IRC3249
#   → FALTANTE: IRC3412
#   → FALTANTE: IRC3411
#   → FALTANTE: IRC3410
#   → FALTANTE: IRC3409
#   → FALTANTE: IRC3408
#   → FALTANTE: IRC3407
#   → FALTANTE: IRC3406
#   → FALTANTE: IRC3405
#   → FALTANTE: IRC3404
#   → FALTANTE: IRC3403
#   → FALTANTE: IRC3402
#   → FALTANTE: IRC3401
#   → FALTANTE: IRC3400
#   → FALTANTE: IRC3563
#   → FALTANTE: IRC3562
#   → FALTANTE: IRC3561
#   → FALTANTE: IRC3560
#   → FALTANTE: IRC3559
#   → FALTANTE: IRC3558
#   → FALTANTE: IRC3557
#   → FALTANTE: IRC3556
#   → FALTANTE: IRC3555
#   → FALTANTE: IRC3554
#   → FALTANTE: IRC3553
#   → FALTANTE: IRC3714
#   → FALTANTE: IRC3713
#   → FALTANTE: IRC3712
#   → FALTANTE: IRC3711
#   → FALTANTE: IRC3710
#   → FALTANTE: IRC3709
#   → FALTANTE: IRC3708
#   → FALTANTE: IRC3707
#   → FALTANTE: IRC3706
#   → FALTANTE: IRC3705
#   → FALTANTE: IRC3864
#   → FALTANTE: IRC3863
#   → FALTANTE: IRC3862
#   → FALTANTE: IRC3861
#   → FALTANTE: IRC3860
#   → FALTANTE: IRC3859
#   → FALTANTE: IRC3858
#   → FALTANTE: IRC3857
#   → FALTANTE: IRC3856
#   → FALTANTE: IRC4020
#   → FALTANTE: IRC4015
#   → FALTANTE: IRC4014
#   → FALTANTE: IRC4013
#   → FALTANTE: IRC4012
#   → FALTANTE: IRC4011
#   → FALTANTE: IRC4010
#   → FALTANTE: IRC4171
#   → FALTANTE: IRC4170
#   → FALTANTE: IRC4169
#   → FALTANTE: IRC4166
#   → FALTANTE: IRC4165
#   → FALTANTE: IRC4164
#   → FALTANTE: IRC4163
#   → FALTANTE: IRC4162
#   → FALTANTE: IRC4161
#   → FALTANTE: IRC4322
#   → FALTANTE: IRC4321
#   → FALTANTE: IRC4320
#   → FALTANTE: IRC4319
#   → FALTANTE: IRC4318
#   → FALTANTE: IRC4317
#   → FALTANTE: IRC4316
#   → FALTANTE: IRC4315
#   → FALTANTE: IRC4314
#   → FALTANTE: IRC4313
#   → FALTANTE: IRC4473
#   → FALTANTE: IRC4472
#   → FALTANTE: IRC4471
#   → FALTANTE: IRC4470
#   → FALTANTE: IRC4469
#   → FALTANTE: IRC4468
#   → FALTANTE: IRC4467
#   → FALTANTE: IRC4466
#   → FALTANTE: IRC4465
#   → FALTANTE: IRC4464
#   → FALTANTE: IRC4622
#   → FALTANTE: IRC4620
#   → FALTANTE: IRC4619
#   → FALTANTE: IRC4618
#   → FALTANTE: IRC4617
#   → FALTANTE: IRC4616
#   → FALTANTE: IRC4615
#   → FALTANTE: IRC4614
#   → FALTANTE: IRC4770
#   → FALTANTE: IRC4769
#   → FALTANTE: IRC4768
#   → FALTANTE: IRC4767
#   → FALTANTE: IRC4766
#   → FALTANTE: IRC4765
#   → FALTANTE: IRC4764
#   → FALTANTE: IRC4763
#   → FALTANTE: IRC4918
#   → FALTANTE: IRC4917
#   → FALTANTE: IRC4916
#   → FALTANTE: IRC4915
#   → FALTANTE: IRC4914
#   → FALTANTE: IRC5069
#   → FALTANTE: IRC5068
#   → FALTANTE: IRC5067
#   → FALTANTE: IRC5066
#   → FALTANTE: IRC5065
#   → FALTANTE: IRC5220
#   → FALTANTE: IRC5219
#   → FALTANTE: IRC5218
#   → FALTANTE: IRC5217
#   → FALTANTE: IRC5216
#   → FALTANTE: IRC5370
#   → FALTANTE: IRC5369
#   → FALTANTE: IRC5368
# ⚠️  No esperados: 0
# 📂 Archivos movidos: 0
#
# 🔍 Revisando carpeta: /content/drive/MyDrive/QLAB PUCP/2022-2024/D - MIDAGRI/imagenes/Anterior/2022_08
# 📦 Total archivos: 187
# ❌ Faltantes: 187
#   → FALTANTE: IRC2056
#   → FALTANTE: IRC2055
#   → FALTANTE: IRC2208
#   → FALTANTE: IRC2207
#   → FALTANTE: IRC2206
#   → FALTANTE: IRC2205
#   → FALTANTE: IRC2204
#   → FALTANTE: IRC2203
#   → FALTANTE: IRC2359
#   → FALTANTE: IRC2358
#   → FALTANTE: IRC2357
#   → FALTANTE: IRC2356
#   → FALTANTE: IRC2355
#   → FALTANTE: IRC2354
#   → FALTANTE: IRC2353
#   → FALTANTE: IRC2352
#   → FALTANTE: IRC2510
#   → FALTANTE: IRC2509
#   → FALTANTE: IRC2508
#   → FALTANTE: IRC2507
#   → FALTANTE: IRC2506
#   → FALTANTE: IRC2505
#   → FALTANTE: IRC2504
#   → FALTANTE: IRC2503
#   → FALTANTE: IRC2502
#   → FALTANTE: IRC2658
#   → FALTANTE: IRC2657
#   → FALTANTE: IRC2656
#   → FALTANTE: IRC2655
#   → FALTANTE: IRC2654
#   → FALTANTE: IRC2653
#   → FALTANTE: IRC2652
#   → FALTANTE: IRC2808
#   → FALTANTE: IRC2807
#   → FALTANTE: IRC2806
#   → FALTANTE: IRC2805
#   → FALTANTE: IRC2804
#   → FALTANTE: IRC2803
#   → FALTANTE: IRC2802
#   → FALTANTE: IRC2959
#   → FALTANTE: IRC2958
#   → FALTANTE: IRC2957
#   → FALTANTE: IRC2956
#   → FALTANTE: IRC2955
#   → FALTANTE: IRC2954
#   → FALTANTE: IRC2953
#   → FALTANTE: IRC2952
#   → FALTANTE: IRC2951
#   → FALTANTE: IRC3111
#   → FALTANTE: IRC3110
#   → FALTANTE: IRC3109
#   → FALTANTE: IRC3108
#   → FALTANTE: IRC3107
#   → FALTANTE: IRC3106
#   → FALTANTE: IRC3105
#   → FALTANTE: IRC3104
#   → FALTANTE: IRC3103
#   → FALTANTE: IRC3102
#   → FALTANTE: IRC3101
#   → FALTANTE: IRC3100
#   → FALTANTE: IRC3262
#   → FALTANTE: IRC3261
#   → FALTANTE: IRC3260
#   → FALTANTE: IRC3259
#   → FALTANTE: IRC3258
#   → FALTANTE: IRC3257
#   → FALTANTE: IRC3256
#   → FALTANTE: IRC3255
#   → FALTANTE: IRC3254
#   → FALTANTE: IRC3253
#   → FALTANTE: IRC3252
#   → FALTANTE: IRC3251
#   → FALTANTE: IRC3250
#   → FALTANTE: IRC3249
#   → FALTANTE: IRC3412
#   → FALTANTE: IRC3411
#   → FALTANTE: IRC3410
#   → FALTANTE: IRC3409
#   → FALTANTE: IRC3408
#   → FALTANTE: IRC3407
#   → FALTANTE: IRC3406
#   → FALTANTE: IRC3405
#   → FALTANTE: IRC3404
#   → FALTANTE: IRC3403
#   → FALTANTE: IRC3402
#   → FALTANTE: IRC3401
#   → FALTANTE: IRC3400
#   → FALTANTE: IRC3563
#   → FALTANTE: IRC3562
#   → FALTANTE: IRC3561
#   → FALTANTE: IRC3560
#   → FALTANTE: IRC3559
#   → FALTANTE: IRC3558
#   → FALTANTE: IRC3557
#   → FALTANTE: IRC3556
#   → FALTANTE: IRC3555
#   → FALTANTE: IRC3554
#   → FALTANTE: IRC3553
#   → FALTANTE: IRC3714
#   → FALTANTE: IRC3713
#   → FALTANTE: IRC3712
#   → FALTANTE: IRC3711
#   → FALTANTE: IRC3710
#   → FALTANTE: IRC3709
#   → FALTANTE: IRC3708
#   → FALTANTE: IRC3707
#   → FALTANTE: IRC3706
#   → FALTANTE: IRC3705
#   → FALTANTE: IRC3864
#   → FALTANTE: IRC3863
#   → FALTANTE: IRC3862
#   → FALTANTE: IRC3861
#   → FALTANTE: IRC3860
#   → FALTANTE: IRC3859
#   → FALTANTE: IRC3858
#   → FALTANTE: IRC3857
#   → FALTANTE: IRC3856
#   → FALTANTE: IRC4020
#   → FALTANTE: IRC4015
#   → FALTANTE: IRC4014
#   → FALTANTE: IRC4013
#   → FALTANTE: IRC4012
#   → FALTANTE: IRC4011
#   → FALTANTE: IRC4010
#   → FALTANTE: IRC4171
#   → FALTANTE: IRC4170
#   → FALTANTE: IRC4169
#   → FALTANTE: IRC4166
#   → FALTANTE: IRC4165
#   → FALTANTE: IRC4164
#   → FALTANTE: IRC4163
#   → FALTANTE: IRC4162
#   → FALTANTE: IRC4161
#   → FALTANTE: IRC4322
#   → FALTANTE: IRC4321
#   → FALTANTE: IRC4320
#   → FALTANTE: IRC4319
#   → FALTANTE: IRC4318
#   → FALTANTE: IRC4317
#   → FALTANTE: IRC4316
#   → FALTANTE: IRC4315
#   → FALTANTE: IRC4314
#   → FALTANTE: IRC4313
#   → FALTANTE: IRC4473
#   → FALTANTE: IRC4472
#   → FALTANTE: IRC4471
#   → FALTANTE: IRC4470
#   → FALTANTE: IRC4469
#   → FALTANTE: IRC4468
#   → FALTANTE: IRC4467
#   → FALTANTE: IRC4466
#   → FALTANTE: IRC4465
#   → FALTANTE: IRC4464
#   → FALTANTE: IRC4622
#   → FALTANTE: IRC4620
#   → FALTANTE: IRC4619
#   → FALTANTE: IRC4618
#   → FALTANTE: IRC4617
#   → FALTANTE: IRC4616
#   → FALTANTE: IRC4615
#   → FALTANTE: IRC4614
#   → FALTANTE: IRC4770
#   → FALTANTE: IRC4769
#   → FALTANTE: IRC4768
#   → FALTANTE: IRC4767
#   → FALTANTE: IRC4766
#   → FALTANTE: IRC4765
#   → FALTANTE: IRC4764
#   → FALTANTE: IRC4763
#   → FALTANTE: IRC4918
#   → FALTANTE: IRC4917
#   → FALTANTE: IRC4916
#   → FALTANTE: IRC4915
#   → FALTANTE: IRC4914
#   → FALTANTE: IRC5069
#   → FALTANTE: IRC5068
#   → FALTANTE: IRC5067
#   → FALTANTE: IRC5066
#   → FALTANTE: IRC5065
#   → FALTANTE: IRC5220
#   → FALTANTE: IRC5219
#   → FALTANTE: IRC5218
#   → FALTANTE: IRC5217
#   → FALTANTE: IRC5216
#   → FALTANTE: IRC5370
#   → FALTANTE: IRC5369
#   → FALTANTE: IRC5368
# ⚠️  No esperados: 0
# 📂 Archivos movidos: 0
#
# 🔍 Revisando carpeta: /content/drive/MyDrive/QLAB PUCP/2022-2024/D - MIDAGRI/imagenes/Anterior/2022_09
# 📦 Total archivos: 187
# ❌ Faltantes: 187
#   → FALTANTE: IRC2056
#   → FALTANTE: IRC2055
#   → FALTANTE: IRC2208
#   → FALTANTE: IRC2207
#   → FALTANTE: IRC2206
#   → FALTANTE: IRC2205
#   → FALTANTE: IRC2204
#   → FALTANTE: IRC2203
#   → FALTANTE: IRC2359
#   → FALTANTE: IRC2358
#   → FALTANTE: IRC2357
#   → FALTANTE: IRC2356
#   → FALTANTE: IRC2355
#   → FALTANTE: IRC2354
#   → FALTANTE: IRC2353
#   → FALTANTE: IRC2352
#   → FALTANTE: IRC2510
#   → FALTANTE: IRC2509
#   → FALTANTE: IRC2508
#   → FALTANTE: IRC2507
#   → FALTANTE: IRC2506
#   → FALTANTE: IRC2505
#   → FALTANTE: IRC2504
#   → FALTANTE: IRC2503
#   → FALTANTE: IRC2502
#   → FALTANTE: IRC2658
#   → FALTANTE: IRC2657
#   → FALTANTE: IRC2656
#   → FALTANTE: IRC2655
#   → FALTANTE: IRC2654
#   → FALTANTE: IRC2653
#   → FALTANTE: IRC2652
#   → FALTANTE: IRC2808
#   → FALTANTE: IRC2807
#   → FALTANTE: IRC2806
#   → FALTANTE: IRC2805
#   → FALTANTE: IRC2804
#   → FALTANTE: IRC2803
#   → FALTANTE: IRC2802
#   → FALTANTE: IRC2959
#   → FALTANTE: IRC2958
#   → FALTANTE: IRC2957
#   → FALTANTE: IRC2956
#   → FALTANTE: IRC2955
#   → FALTANTE: IRC2954
#   → FALTANTE: IRC2953
#   → FALTANTE: IRC2952
#   → FALTANTE: IRC2951
#   → FALTANTE: IRC3111
#   → FALTANTE: IRC3110
#   → FALTANTE: IRC3109
#   → FALTANTE: IRC3108
#   → FALTANTE: IRC3107
#   → FALTANTE: IRC3106
#   → FALTANTE: IRC3105
#   → FALTANTE: IRC3104
#   → FALTANTE: IRC3103
#   → FALTANTE: IRC3102
#   → FALTANTE: IRC3101
#   → FALTANTE: IRC3100
#   → FALTANTE: IRC3262
#   → FALTANTE: IRC3261
#   → FALTANTE: IRC3260
#   → FALTANTE: IRC3259
#   → FALTANTE: IRC3258
#   → FALTANTE: IRC3257
#   → FALTANTE: IRC3256
#   → FALTANTE: IRC3255
#   → FALTANTE: IRC3254
#   → FALTANTE: IRC3253
#   → FALTANTE: IRC3252
#   → FALTANTE: IRC3251
#   → FALTANTE: IRC3250
#   → FALTANTE: IRC3249
#   → FALTANTE: IRC3412
#   → FALTANTE: IRC3411
#   → FALTANTE: IRC3410
#   → FALTANTE: IRC3409
#   → FALTANTE: IRC3408
#   → FALTANTE: IRC3407
#   → FALTANTE: IRC3406
#   → FALTANTE: IRC3405
#   → FALTANTE: IRC3404
#   → FALTANTE: IRC3403
#   → FALTANTE: IRC3402
#   → FALTANTE: IRC3401
#   → FALTANTE: IRC3400
#   → FALTANTE: IRC3563
#   → FALTANTE: IRC3562
#   → FALTANTE: IRC3561
#   → FALTANTE: IRC3560
#   → FALTANTE: IRC3559
#   → FALTANTE: IRC3558
#   → FALTANTE: IRC3557
#   → FALTANTE: IRC3556
#   → FALTANTE: IRC3555
#   → FALTANTE: IRC3554
#   → FALTANTE: IRC3553
#   → FALTANTE: IRC3714
#   → FALTANTE: IRC3713
#   → FALTANTE: IRC3712
#   → FALTANTE: IRC3711
#   → FALTANTE: IRC3710
#   → FALTANTE: IRC3709
#   → FALTANTE: IRC3708
#   → FALTANTE: IRC3707
#   → FALTANTE: IRC3706
#   → FALTANTE: IRC3705
#   → FALTANTE: IRC3864
#   → FALTANTE: IRC3863
#   → FALTANTE: IRC3862
#   → FALTANTE: IRC3861
#   → FALTANTE: IRC3860
#   → FALTANTE: IRC3859
#   → FALTANTE: IRC3858
#   → FALTANTE: IRC3857
#   → FALTANTE: IRC3856
#   → FALTANTE: IRC4020
#   → FALTANTE: IRC4015
#   → FALTANTE: IRC4014
#   → FALTANTE: IRC4013
#   → FALTANTE: IRC4012
#   → FALTANTE: IRC4011
#   → FALTANTE: IRC4010
#   → FALTANTE: IRC4171
#   → FALTANTE: IRC4170
#   → FALTANTE: IRC4169
#   → FALTANTE: IRC4166
#   → FALTANTE: IRC4165
#   → FALTANTE: IRC4164
#   → FALTANTE: IRC4163
#   → FALTANTE: IRC4162
#   → FALTANTE: IRC4161
#   → FALTANTE: IRC4322
#   → FALTANTE: IRC4321
#   → FALTANTE: IRC4320
#   → FALTANTE: IRC4319
#   → FALTANTE: IRC4318
#   → FALTANTE: IRC4317
#   → FALTANTE: IRC4316
#   → FALTANTE: IRC4315
#   → FALTANTE: IRC4314
#   → FALTANTE: IRC4313
#   → FALTANTE: IRC4473
#   → FALTANTE: IRC4472
#   → FALTANTE: IRC4471
#   → FALTANTE: IRC4470
#   → FALTANTE: IRC4469
#   → FALTANTE: IRC4468
#   → FALTANTE: IRC4467
#   → FALTANTE: IRC4466
#   → FALTANTE: IRC4465
#   → FALTANTE: IRC4464
#   → FALTANTE: IRC4622
#   → FALTANTE: IRC4620
#   → FALTANTE: IRC4619
#   → FALTANTE: IRC4618
#   → FALTANTE: IRC4617
#   → FALTANTE: IRC4616
#   → FALTANTE: IRC4615
#   → FALTANTE: IRC4614
#   → FALTANTE: IRC4770
#   → FALTANTE: IRC4769
#   → FALTANTE: IRC4768
#   → FALTANTE: IRC4767
#   → FALTANTE: IRC4766
#   → FALTANTE: IRC4765
#   → FALTANTE: IRC4764
#   → FALTANTE: IRC4763
#   → FALTANTE: IRC4918
#   → FALTANTE: IRC4917
#   → FALTANTE: IRC4916
#   → FALTANTE: IRC4915
#   → FALTANTE: IRC4914
#   → FALTANTE: IRC5069
#   → FALTANTE: IRC5068
#   → FALTANTE: IRC5067
#   → FALTANTE: IRC5066
#   → FALTANTE: IRC5065
#   → FALTANTE: IRC5220
#   → FALTANTE: IRC5219
#   → FALTANTE: IRC5218
#   → FALTANTE: IRC5217
#   → FALTANTE: IRC5216
#   → FALTANTE: IRC5370
#   → FALTANTE: IRC5369
#   → FALTANTE: IRC5368
# ⚠️  No esperados: 0
# 📂 Archivos movidos: 0
#
# 🔍 Revisando carpeta: /content/drive/MyDrive/QLAB PUCP/2022-2024/D - MIDAGRI/imagenes/Anterior/2022_10
# 📦 Total archivos: 187
# ❌ Faltantes: 187
#   → FALTANTE: IRC2056
#   → FALTANTE: IRC2055
#   → FALTANTE: IRC2208
#   → FALTANTE: IRC2207
#   → FALTANTE: IRC2206
#   → FALTANTE: IRC2205
#   → FALTANTE: IRC2204
#   → FALTANTE: IRC2203
#   → FALTANTE: IRC2359
#   → FALTANTE: IRC2358
#   → FALTANTE: IRC2357
#   → FALTANTE: IRC2356
#   → FALTANTE: IRC2355
#   → FALTANTE: IRC2354
#   → FALTANTE: IRC2353
#   → FALTANTE: IRC2352
#   → FALTANTE: IRC2510
#   → FALTANTE: IRC2509
#   → FALTANTE: IRC2508
#   → FALTANTE: IRC2507
#   → FALTANTE: IRC2506
#   → FALTANTE: IRC2505
#   → FALTANTE: IRC2504
#   → FALTANTE: IRC2503
#   → FALTANTE: IRC2502
#   → FALTANTE: IRC2658
#   → FALTANTE: IRC2657
#   → FALTANTE: IRC2656
#   → FALTANTE: IRC2655
#   → FALTANTE: IRC2654
#   → FALTANTE: IRC2653
#   → FALTANTE: IRC2652
#   → FALTANTE: IRC2808
#   → FALTANTE: IRC2807
#   → FALTANTE: IRC2806
#   → FALTANTE: IRC2805
#   → FALTANTE: IRC2804
#   → FALTANTE: IRC2803
#   → FALTANTE: IRC2802
#   → FALTANTE: IRC2959
#   → FALTANTE: IRC2958
#   → FALTANTE: IRC2957
#   → FALTANTE: IRC2956
#   → FALTANTE: IRC2955
#   → FALTANTE: IRC2954
#   → FALTANTE: IRC2953
#   → FALTANTE: IRC2952
#   → FALTANTE: IRC2951
#   → FALTANTE: IRC3111
#   → FALTANTE: IRC3110
#   → FALTANTE: IRC3109
#   → FALTANTE: IRC3108
#   → FALTANTE: IRC3107
#   → FALTANTE: IRC3106
#   → FALTANTE: IRC3105
#   → FALTANTE: IRC3104
#   → FALTANTE: IRC3103
#   → FALTANTE: IRC3102
#   → FALTANTE: IRC3101
#   → FALTANTE: IRC3100
#   → FALTANTE: IRC3262
#   → FALTANTE: IRC3261
#   → FALTANTE: IRC3260
#   → FALTANTE: IRC3259
#   → FALTANTE: IRC3258
#   → FALTANTE: IRC3257
#   → FALTANTE: IRC3256
#   → FALTANTE: IRC3255
#   → FALTANTE: IRC3254
#   → FALTANTE: IRC3253
#   → FALTANTE: IRC3252
#   → FALTANTE: IRC3251
#   → FALTANTE: IRC3250
#   → FALTANTE: IRC3249
#   → FALTANTE: IRC3412
#   → FALTANTE: IRC3411
#   → FALTANTE: IRC3410
#   → FALTANTE: IRC3409
#   → FALTANTE: IRC3408
#   → FALTANTE: IRC3407
#   → FALTANTE: IRC3406
#   → FALTANTE: IRC3405
#   → FALTANTE: IRC3404
#   → FALTANTE: IRC3403
#   → FALTANTE: IRC3402
#   → FALTANTE: IRC3401
#   → FALTANTE: IRC3400
#   → FALTANTE: IRC3563
#   → FALTANTE: IRC3562
#   → FALTANTE: IRC3561
#   → FALTANTE: IRC3560
#   → FALTANTE: IRC3559
#   → FALTANTE: IRC3558
#   → FALTANTE: IRC3557
#   → FALTANTE: IRC3556
#   → FALTANTE: IRC3555
#   → FALTANTE: IRC3554
#   → FALTANTE: IRC3553
#   → FALTANTE: IRC3714
#   → FALTANTE: IRC3713
#   → FALTANTE: IRC3712
#   → FALTANTE: IRC3711
#   → FALTANTE: IRC3710
#   → FALTANTE: IRC3709
#   → FALTANTE: IRC3708
#   → FALTANTE: IRC3707
#   → FALTANTE: IRC3706
#   → FALTANTE: IRC3705
#   → FALTANTE: IRC3864
#   → FALTANTE: IRC3863
#   → FALTANTE: IRC3862
#   → FALTANTE: IRC3861
#   → FALTANTE: IRC3860
#   → FALTANTE: IRC3859
#   → FALTANTE: IRC3858
#   → FALTANTE: IRC3857
#   → FALTANTE: IRC3856
#   → FALTANTE: IRC4020
#   → FALTANTE: IRC4015
#   → FALTANTE: IRC4014
#   → FALTANTE: IRC4013
#   → FALTANTE: IRC4012
#   → FALTANTE: IRC4011
#   → FALTANTE: IRC4010
#   → FALTANTE: IRC4171
#   → FALTANTE: IRC4170
#   → FALTANTE: IRC4169
#   → FALTANTE: IRC4166
#   → FALTANTE: IRC4165
#   → FALTANTE: IRC4164
#   → FALTANTE: IRC4163
#   → FALTANTE: IRC4162
#   → FALTANTE: IRC4161
#   → FALTANTE: IRC4322
#   → FALTANTE: IRC4321
#   → FALTANTE: IRC4320
#   → FALTANTE: IRC4319
#   → FALTANTE: IRC4318
#   → FALTANTE: IRC4317
#   → FALTANTE: IRC4316
#   → FALTANTE: IRC4315
#   → FALTANTE: IRC4314
#   → FALTANTE: IRC4313
#   → FALTANTE: IRC4473
#   → FALTANTE: IRC4472
#   → FALTANTE: IRC4471
#   → FALTANTE: IRC4470
#   → FALTANTE: IRC4469
#   → FALTANTE: IRC4468
#   → FALTANTE: IRC4467
#   → FALTANTE: IRC4466
#   → FALTANTE: IRC4465
#   → FALTANTE: IRC4464
#   → FALTANTE: IRC4622
#   → FALTANTE: IRC4620
#   → FALTANTE: IRC4619
#   → FALTANTE: IRC4618
#   → FALTANTE: IRC4617
#   → FALTANTE: IRC4616
#   → FALTANTE: IRC4615
#   → FALTANTE: IRC4614
#   → FALTANTE: IRC4770
#   → FALTANTE: IRC4769
#   → FALTANTE: IRC4768
#   → FALTANTE: IRC4767
#   → FALTANTE: IRC4766
#   → FALTANTE: IRC4765
#   → FALTANTE: IRC4764
#   → FALTANTE: IRC4763
#   → FALTANTE: IRC4918
#   → FALTANTE: IRC4917
#   → FALTANTE: IRC4916
#   → FALTANTE: IRC4915
#   → FALTANTE: IRC4914
#   → FALTANTE: IRC5069
#   → FALTANTE: IRC5068
#   → FALTANTE: IRC5067
#   → FALTANTE: IRC5066
#   → FALTANTE: IRC5065
#   → FALTANTE: IRC5220
#   → FALTANTE: IRC5219
#   → FALTANTE: IRC5218
#   → FALTANTE: IRC5217
#   → FALTANTE: IRC5216
#   → FALTANTE: IRC5370
#   → FALTANTE: IRC5369
#   → FALTANTE: IRC5368
# ⚠️  No esperados: 0
# 📂 Archivos movidos: 0
#
# 🔍 Revisando carpeta: /content/drive/MyDrive/QLAB PUCP/2022-2024/D - MIDAGRI/imagenes/Anterior/2022_11
# 📦 Total archivos: 187
# ❌ Faltantes: 187
#   → FALTANTE: IRC2056
#   → FALTANTE: IRC2055
#   → FALTANTE: IRC2208
#   → FALTANTE: IRC2207
#   → FALTANTE: IRC2206
#   → FALTANTE: IRC2205
#   → FALTANTE: IRC2204
#   → FALTANTE: IRC2203
#   → FALTANTE: IRC2359
#   → FALTANTE: IRC2358
#   → FALTANTE: IRC2357
#   → FALTANTE: IRC2356
#   → FALTANTE: IRC2355
#   → FALTANTE: IRC2354
#   → FALTANTE: IRC2353
#   → FALTANTE: IRC2352
#   → FALTANTE: IRC2510
#   → FALTANTE: IRC2509
#   → FALTANTE: IRC2508
#   → FALTANTE: IRC2507
#   → FALTANTE: IRC2506
#   → FALTANTE: IRC2505
#   → FALTANTE: IRC2504
#   → FALTANTE: IRC2503
#   → FALTANTE: IRC2502
#   → FALTANTE: IRC2658
#   → FALTANTE: IRC2657
#   → FALTANTE: IRC2656
#   → FALTANTE: IRC2655
#   → FALTANTE: IRC2654
#   → FALTANTE: IRC2653
#   → FALTANTE: IRC2652
#   → FALTANTE: IRC2808
#   → FALTANTE: IRC2807
#   → FALTANTE: IRC2806
#   → FALTANTE: IRC2805
#   → FALTANTE: IRC2804
#   → FALTANTE: IRC2803
#   → FALTANTE: IRC2802
#   → FALTANTE: IRC2959
#   → FALTANTE: IRC2958
#   → FALTANTE: IRC2957
#   → FALTANTE: IRC2956
#   → FALTANTE: IRC2955
#   → FALTANTE: IRC2954
#   → FALTANTE: IRC2953
#   → FALTANTE: IRC2952
#   → FALTANTE: IRC2951
#   → FALTANTE: IRC3111
#   → FALTANTE: IRC3110
#   → FALTANTE: IRC3109
#   → FALTANTE: IRC3108
#   → FALTANTE: IRC3107
#   → FALTANTE: IRC3106
#   → FALTANTE: IRC3105
#   → FALTANTE: IRC3104
#   → FALTANTE: IRC3103
#   → FALTANTE: IRC3102
#   → FALTANTE: IRC3101
#   → FALTANTE: IRC3100
#   → FALTANTE: IRC3262
#   → FALTANTE: IRC3261
#   → FALTANTE: IRC3260
#   → FALTANTE: IRC3259
#   → FALTANTE: IRC3258
#   → FALTANTE: IRC3257
#   → FALTANTE: IRC3256
#   → FALTANTE: IRC3255
#   → FALTANTE: IRC3254
#   → FALTANTE: IRC3253
#   → FALTANTE: IRC3252
#   → FALTANTE: IRC3251
#   → FALTANTE: IRC3250
#   → FALTANTE: IRC3249
#   → FALTANTE: IRC3412
#   → FALTANTE: IRC3411
#   → FALTANTE: IRC3410
#   → FALTANTE: IRC3409
#   → FALTANTE: IRC3408
#   → FALTANTE: IRC3407
#   → FALTANTE: IRC3406
#   → FALTANTE: IRC3405
#   → FALTANTE: IRC3404
#   → FALTANTE: IRC3403
#   → FALTANTE: IRC3402
#   → FALTANTE: IRC3401
#   → FALTANTE: IRC3400
#   → FALTANTE: IRC3563
#   → FALTANTE: IRC3562
#   → FALTANTE: IRC3561
#   → FALTANTE: IRC3560
#   → FALTANTE: IRC3559
#   → FALTANTE: IRC3558
#   → FALTANTE: IRC3557
#   → FALTANTE: IRC3556
#   → FALTANTE: IRC3555
#   → FALTANTE: IRC3554
#   → FALTANTE: IRC3553
#   → FALTANTE: IRC3714
#   → FALTANTE: IRC3713
#   → FALTANTE: IRC3712
#   → FALTANTE: IRC3711
#   → FALTANTE: IRC3710
#   → FALTANTE: IRC3709
#   → FALTANTE: IRC3708
#   → FALTANTE: IRC3707
#   → FALTANTE: IRC3706
#   → FALTANTE: IRC3705
#   → FALTANTE: IRC3864
#   → FALTANTE: IRC3863
#   → FALTANTE: IRC3862
#   → FALTANTE: IRC3861
#   → FALTANTE: IRC3860
#   → FALTANTE: IRC3859
#   → FALTANTE: IRC3858
#   → FALTANTE: IRC3857
#   → FALTANTE: IRC3856
#   → FALTANTE: IRC4020
#   → FALTANTE: IRC4015
#   → FALTANTE: IRC4014
#   → FALTANTE: IRC4013
#   → FALTANTE: IRC4012
#   → FALTANTE: IRC4011
#   → FALTANTE: IRC4010
#   → FALTANTE: IRC4171
#   → FALTANTE: IRC4170
#   → FALTANTE: IRC4169
#   → FALTANTE: IRC4166
#   → FALTANTE: IRC4165
#   → FALTANTE: IRC4164
#   → FALTANTE: IRC4163
#   → FALTANTE: IRC4162
#   → FALTANTE: IRC4161
#   → FALTANTE: IRC4322
#   → FALTANTE: IRC4321
#   → FALTANTE: IRC4320
#   → FALTANTE: IRC4319
#   → FALTANTE: IRC4318
#   → FALTANTE: IRC4317
#   → FALTANTE: IRC4316
#   → FALTANTE: IRC4315
#   → FALTANTE: IRC4314
#   → FALTANTE: IRC4313
#   → FALTANTE: IRC4473
#   → FALTANTE: IRC4472
#   → FALTANTE: IRC4471
#   → FALTANTE: IRC4470
#   → FALTANTE: IRC4469
#   → FALTANTE: IRC4468
#   → FALTANTE: IRC4467
#   → FALTANTE: IRC4466
#   → FALTANTE: IRC4465
#   → FALTANTE: IRC4464
#   → FALTANTE: IRC4622
#   → FALTANTE: IRC4620
#   → FALTANTE: IRC4619
#   → FALTANTE: IRC4618
#   → FALTANTE: IRC4617
#   → FALTANTE: IRC4616
#   → FALTANTE: IRC4615
#   → FALTANTE: IRC4614
#   → FALTANTE: IRC4770
#   → FALTANTE: IRC4769
#   → FALTANTE: IRC4768
#   → FALTANTE: IRC4767
#   → FALTANTE: IRC4766
#   → FALTANTE: IRC4765
#   → FALTANTE: IRC4764
#   → FALTANTE: IRC4763
#   → FALTANTE: IRC4918
#   → FALTANTE: IRC4917
#   → FALTANTE: IRC4916
#   → FALTANTE: IRC4915
#   → FALTANTE: IRC4914
#   → FALTANTE: IRC5069
#   → FALTANTE: IRC5068
#   → FALTANTE: IRC5067
#   → FALTANTE: IRC5066
#   → FALTANTE: IRC5065
#   → FALTANTE: IRC5220
#   → FALTANTE: IRC5219
#   → FALTANTE: IRC5218
#   → FALTANTE: IRC5217
#   → FALTANTE: IRC5216
#   → FALTANTE: IRC5370
#   → FALTANTE: IRC5369
#   → FALTANTE: IRC5368
# ⚠️  No esperados: 0
# 📂 Archivos movidos: 0
#
# 🔍 Revisando carpeta: /content/drive/MyDrive/QLAB PUCP/2022-2024/D - MIDAGRI/imagenes/Anterior/2022_12
# 📦 Total archivos: 365
# ❌ Faltantes: 187
#   → FALTANTE: IRC2056
#   → FALTANTE: IRC2055
#   → FALTANTE: IRC2208
#   → FALTANTE: IRC2207
#   → FALTANTE: IRC2206
#   → FALTANTE: IRC2205
#   → FALTANTE: IRC2204
#   → FALTANTE: IRC2203
#   → FALTANTE: IRC2359
#   → FALTANTE: IRC2358
#   → FALTANTE: IRC2357
#   → FALTANTE: IRC2356
#   → FALTANTE: IRC2355
#   → FALTANTE: IRC2354
#   → FALTANTE: IRC2353
#   → FALTANTE: IRC2352
#   → FALTANTE: IRC2510
#   → FALTANTE: IRC2509
#   → FALTANTE: IRC2508
#   → FALTANTE: IRC2507
#   → FALTANTE: IRC2506
#   → FALTANTE: IRC2505
#   → FALTANTE: IRC2504
#   → FALTANTE: IRC2503
#   → FALTANTE: IRC2502
#   → FALTANTE: IRC2658
#   → FALTANTE: IRC2657
#   → FALTANTE: IRC2656
#   → FALTANTE: IRC2655
#   → FALTANTE: IRC2654
#   → FALTANTE: IRC2653
#   → FALTANTE: IRC2652
#   → FALTANTE: IRC2808
#   → FALTANTE: IRC2807
#   → FALTANTE: IRC2806
#   → FALTANTE: IRC2805
#   → FALTANTE: IRC2804
#   → FALTANTE: IRC2803
#   → FALTANTE: IRC2802
#   → FALTANTE: IRC2959
#   → FALTANTE: IRC2958
#   → FALTANTE: IRC2957
#   → FALTANTE: IRC2956
#   → FALTANTE: IRC2955
#   → FALTANTE: IRC2954
#   → FALTANTE: IRC2953
#   → FALTANTE: IRC2952
#   → FALTANTE: IRC2951
#   → FALTANTE: IRC3111
#   → FALTANTE: IRC3110
#   → FALTANTE: IRC3109
#   → FALTANTE: IRC3108
#   → FALTANTE: IRC3107
#   → FALTANTE: IRC3106
#   → FALTANTE: IRC3105
#   → FALTANTE: IRC3104
#   → FALTANTE: IRC3103
#   → FALTANTE: IRC3102
#   → FALTANTE: IRC3101
#   → FALTANTE: IRC3100
#   → FALTANTE: IRC3262
#   → FALTANTE: IRC3261
#   → FALTANTE: IRC3260
#   → FALTANTE: IRC3259
#   → FALTANTE: IRC3258
#   → FALTANTE: IRC3257
#   → FALTANTE: IRC3256
#   → FALTANTE: IRC3255
#   → FALTANTE: IRC3254
#   → FALTANTE: IRC3253
#   → FALTANTE: IRC3252
#   → FALTANTE: IRC3251
#   → FALTANTE: IRC3250
#   → FALTANTE: IRC3249
#   → FALTANTE: IRC3412
#   → FALTANTE: IRC3411
#   → FALTANTE: IRC3410
#   → FALTANTE: IRC3409
#   → FALTANTE: IRC3408
#   → FALTANTE: IRC3407
#   → FALTANTE: IRC3406
#   → FALTANTE: IRC3405
#   → FALTANTE: IRC3404
#   → FALTANTE: IRC3403
#   → FALTANTE: IRC3402
#   → FALTANTE: IRC3401
#   → FALTANTE: IRC3400
#   → FALTANTE: IRC3563
#   → FALTANTE: IRC3562
#   → FALTANTE: IRC3561
#   → FALTANTE: IRC3560
#   → FALTANTE: IRC3559
#   → FALTANTE: IRC3558
#   → FALTANTE: IRC3557
#   → FALTANTE: IRC3556
#   → FALTANTE: IRC3555
#   → FALTANTE: IRC3554
#   → FALTANTE: IRC3553
#   → FALTANTE: IRC3714
#   → FALTANTE: IRC3713
#   → FALTANTE: IRC3712
#   → FALTANTE: IRC3711
#   → FALTANTE: IRC3710
#   → FALTANTE: IRC3709
#   → FALTANTE: IRC3708
#   → FALTANTE: IRC3707
#   → FALTANTE: IRC3706
#   → FALTANTE: IRC3705
#   → FALTANTE: IRC3864
#   → FALTANTE: IRC3863
#   → FALTANTE: IRC3862
#   → FALTANTE: IRC3861
#   → FALTANTE: IRC3860
#   → FALTANTE: IRC3859
#   → FALTANTE: IRC3858
#   → FALTANTE: IRC3857
#   → FALTANTE: IRC3856
#   → FALTANTE: IRC4020
#   → FALTANTE: IRC4015
#   → FALTANTE: IRC4014
#   → FALTANTE: IRC4013
#   → FALTANTE: IRC4012
#   → FALTANTE: IRC4011
#   → FALTANTE: IRC4010
#   → FALTANTE: IRC4171
#   → FALTANTE: IRC4170
#   → FALTANTE: IRC4169
#   → FALTANTE: IRC4166
#   → FALTANTE: IRC4165
#   → FALTANTE: IRC4164
#   → FALTANTE: IRC4163
#   → FALTANTE: IRC4162
#   → FALTANTE: IRC4161
#   → FALTANTE: IRC4322
#   → FALTANTE: IRC4321
#   → FALTANTE: IRC4320
#   → FALTANTE: IRC4319
#   → FALTANTE: IRC4318
#   → FALTANTE: IRC4317
#   → FALTANTE: IRC4316
#   → FALTANTE: IRC4315
#   → FALTANTE: IRC4314
#   → FALTANTE: IRC4313
#   → FALTANTE: IRC4473
#   → FALTANTE: IRC4472
#   → FALTANTE: IRC4471
#   → FALTANTE: IRC4470
#   → FALTANTE: IRC4469
#   → FALTANTE: IRC4468
#   → FALTANTE: IRC4467
#   → FALTANTE: IRC4466
#   → FALTANTE: IRC4465
#   → FALTANTE: IRC4464
#   → FALTANTE: IRC4622
#   → FALTANTE: IRC4620
#   → FALTANTE: IRC4619
#   → FALTANTE: IRC4618
#   → FALTANTE: IRC4617
#   → FALTANTE: IRC4616
#   → FALTANTE: IRC4615
#   → FALTANTE: IRC4614
#   → FALTANTE: IRC4770
#   → FALTANTE: IRC4769
#   → FALTANTE: IRC4768
#   → FALTANTE: IRC4767
#   → FALTANTE: IRC4766
#   → FALTANTE: IRC4765
#   → FALTANTE: IRC4764
#   → FALTANTE: IRC4763
#   → FALTANTE: IRC4918
#   → FALTANTE: IRC4917
#   → FALTANTE: IRC4916
#   → FALTANTE: IRC4915
#   → FALTANTE: IRC4914
#   → FALTANTE: IRC5069
#   → FALTANTE: IRC5068
#   → FALTANTE: IRC5067
#   → FALTANTE: IRC5066
#   → FALTANTE: IRC5065
#   → FALTANTE: IRC5220
#   → FALTANTE: IRC5219
#   → FALTANTE: IRC5218
#   → FALTANTE: IRC5217
#   → FALTANTE: IRC5216
#   → FALTANTE: IRC5370
#   → FALTANTE: IRC5369
#   → FALTANTE: IRC5368
# ⚠️  No esperados: 0
# 📂 Archivos movidos: 0
